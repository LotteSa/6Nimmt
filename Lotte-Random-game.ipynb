# %%
import random

# Class for a card
class Card:
    def __init__(self, value):
        self.value = value
        self.minus_points = self.calculate_minus_points(value)

    def calculate_minus_points(self, value):
        if value == 55:  # Card with the value 55 always has 7 penalty points
            return 7
        elif value % 10 == 0:  # Divisible by 10
            return 3
        elif value % 5 == 0:  # Ends with 5
            return 2
        elif str(value) == str(value)[::-1]:  # Palindrome (same forwards and backwards)
            return 5
        else:
            return 1

    def __str__(self):
        return f"{self.value} (Minuspunkte: {self.minus_points})"

# Class for a player
class Player:
    def __init__(self, name):
        self.name = name
        self.hand = []
        self.points = 0

    def draw_cards(self, deck, num_cards=10):
        for _ in range(num_cards):
            if deck:
                self.hand.append(deck.pop())

    def choose_card(self):
        if not self.hand:
            return None
        chosen_card = random.choice(self.hand)
        self.hand.remove(chosen_card)
        return chosen_card

# Function to initialize the game
def initialize_game(num_players):
    # Create a deck of cards (1 to 104)
    deck = [Card(value) for value in range(1, 105)]
    random.shuffle(deck)

    # Create players
    players = [Player(f"Player {i + 1}") for i in range(num_players)]

    # Each player draws 10 cards
    for player in players:
        player.draw_cards(deck)

    # Initialize middle piles with the first four cards from the deck
    middle_piles = [[deck.pop()] for _ in range(4)]

    return players, middle_piles

# Function to play a round of the game
def play_round(players, middle_piles):
    chosen_cards = {}

    # Each player chooses a card and stores it in chosen_cards dictionary
    for player in players:
        chosen_card = player.choose_card()
        if chosen_card:
            chosen_cards[player.name] = chosen_card

    print("\nChosen cards before sorting:")
    for player_name, card in chosen_cards.items():
        print(f"{player_name} chooses {card}")

    # Sort chosen cards by their values (ascending order)
    sorted_chosen_cards = sorted(chosen_cards.items(), key=lambda x: x[1].value)

    # Place chosen cards on the middle piles or take the pile if necessary
    for player_name, card in sorted_chosen_cards:
        placed = False

        # Find the pile with the highest top card that is still lower than the chosen card.
        best_pile_index = -1
        best_top_value = -1

        for i in range(len(middle_piles)):
            top_card_value = middle_piles[i][-1].value

            if top_card_value < card.value and top_card_value > best_top_value:
                best_top_value = top_card_value
                best_pile_index = i

        if best_pile_index != -1:
            middle_piles[best_pile_index].append(card)
            print(f"{player_name} places {card} on Middle pile {best_pile_index + 1}")
            placed = True

        if not placed:
            # If no suitable pile was found, take the pile with the fewest cards.
            min_length_index = min(range(len(middle_piles)), key=lambda i: len(middle_piles[i]))

            points_gained = sum(c.minus_points for c in middle_piles[min_length_index])
            players[[p.name for p in players].index(player_name)].points += points_gained

            print(f"{player_name} takes Middle pile {min_length_index + 1} with Minuspunkten: {points_gained}.")

            # Clear the pile after taking it and add their own card as new pile.
            middle_piles[min_length_index] = [card]
            print(f"{player_name} places their own card {card} as new Middle pile {min_length_index + 1}.")

# Main function to run the game
def play_game(num_players):
    players, middle_piles = initialize_game(num_players)

    print("Initial hands:")
    for player in players:
        print(f"{player.name}'s hand: {[str(card) for card in player.hand]}")

    print("\nMiddle piles before starting:")
    for i, pile in enumerate(middle_piles):
        print(f"Middle pile {i + 1}: {[str(card) for card in pile]}")

    # Play rounds until all cards are played
    round_number = 1
    while any(player.hand for player in players):
        print(f"\n--- Round {round_number} ---")
        play_round(players, middle_piles)

        print("\nMiddle piles after playing the round:")
        for i, pile in enumerate(middle_piles):
            print(f"Middle pile {i + 1}: {[str(card) for card in pile]}")

        print("\nCurrent scores:")
        for player in players:
            print(f"{player.name} has {player.points} Minuspunkte.")

        round_number += 1

    # Display final scores
    print("\n--- Game Over ---")
    print("Final scores:")
    for player in players:
        print(f"{player.name} has {player.points} Minuspunkte.")

# Start the game with user input for number of players
num_players = int(input("Enter the number of players: "))
play_game(num_players)
# Out:
# Enter the number of players:  2
# Initial hands:
# Player 1's hand: ['41 (Minuspunkte: 1)', '95 (Minuspunkte: 2)', '19 (Minuspunkte: 1)', '87 (Minuspunkte: 1)', '27 (Minuspunkte: 1)', '51 (Minuspunkte: 1)', '80 (Minuspunkte: 3)', '99 (Minuspunkte: 5)', '4 (Minuspunkte: 5)', '94 (Minuspunkte: 1)']
# Player 2's hand: ['8 (Minuspunkte: 5)', '14 (Minuspunkte: 1)', '78 (Minuspunkte: 1)', '45 (Minuspunkte: 2)', '43 (Minuspunkte: 1)', '44 (Minuspunkte: 5)', '96 (Minuspunkte: 1)', '33 (Minuspunkte: 5)', '12 (Minuspunkte: 1)', '74 (Minuspunkte: 1)']
#
# Middle piles before starting:
# Middle pile 1: ['61 (Minuspunkte: 1)']
# Middle pile 2: ['32 (Minuspunkte: 1)']
# Middle pile 3: ['52 (Minuspunkte: 1)']
# Middle pile 4: ['35 (Minuspunkte: 2)']
#
# --- Round 1 ---
#
# Chosen cards before sorting:
# Player 1 chooses 19 (Minuspunkte: 1)
# Player 2 chooses 14 (Minuspunkte: 1)
# Player 2 takes Middle pile 1 with Minuspunkten: 1.
# Player 2 places their own card 14 (Minuspunkte: 1) as new Middle pile 1.
# Player 1 places 19 (Minuspunkte: 1) on Middle pile 1
#
# Middle piles after playing the round:
# Middle pile 1: ['14 (Minuspunkte: 1)', '19 (Minuspunkte: 1)']
# Middle pile 2: ['32 (Minuspunkte: 1)']
# Middle pile 3: ['52 (Minuspunkte: 1)']
# Middle pile 4: ['35 (Minuspunkte: 2)']
#
# Current scores:
# Player 1 has 0 Minuspunkte.
# Player 2 has 1 Minuspunkte.
#
# --- Round 2 ---
#
# Chosen cards before sorting:
# Player 1 chooses 87 (Minuspunkte: 1)
# Player 2 chooses 12 (Minuspunkte: 1)
# Player 2 takes Middle pile 2 with Minuspunkten: 1.
# Player 2 places their own card 12 (Minuspunkte: 1) as new Middle pile 2.
# Player 1 places 87 (Minuspunkte: 1) on Middle pile 3
#
# Middle piles after playing the round:
# Middle pile 1: ['14 (Minuspunkte: 1)', '19 (Minuspunkte: 1)']
# Middle pile 2: ['12 (Minuspunkte: 1)']
# Middle pile 3: ['52 (Minuspunkte: 1)', '87 (Minuspunkte: 1)']
# Middle pile 4: ['35 (Minuspunkte: 2)']
#
# Current scores:
# Player 1 has 0 Minuspunkte.
# Player 2 has 2 Minuspunkte.
#
# --- Round 3 ---
#
# Chosen cards before sorting:
# Player 1 chooses 27 (Minuspunkte: 1)
# Player 2 chooses 44 (Minuspunkte: 5)
# Player 1 places 27 (Minuspunkte: 1) on Middle pile 1
# Player 2 places 44 (Minuspunkte: 5) on Middle pile 4
#
# Middle piles after playing the round:
# Middle pile 1: ['14 (Minuspunkte: 1)', '19 (Minuspunkte: 1)', '27 (Minuspunkte: 1)']
# Middle pile 2: ['12 (Minuspunkte: 1)']
# Middle pile 3: ['52 (Minuspunkte: 1)', '87 (Minuspunkte: 1)']
# Middle pile 4: ['35 (Minuspunkte: 2)', '44 (Minuspunkte: 5)']
#
# Current scores:
# Player 1 has 0 Minuspunkte.
# Player 2 has 2 Minuspunkte.
#
# --- Round 4 ---
#
# Chosen cards before sorting:
# Player 1 chooses 4 (Minuspunkte: 5)
# Player 2 chooses 74 (Minuspunkte: 1)
# Player 1 takes Middle pile 2 with Minuspunkten: 1.
# Player 1 places their own card 4 (Minuspunkte: 5) as new Middle pile 2.
# Player 2 places 74 (Minuspunkte: 1) on Middle pile 4
#
# Middle piles after playing the round:
# Middle pile 1: ['14 (Minuspunkte: 1)', '19 (Minuspunkte: 1)', '27 (Minuspunkte: 1)']
# Middle pile 2: ['4 (Minuspunkte: 5)']
# Middle pile 3: ['52 (Minuspunkte: 1)', '87 (Minuspunkte: 1)']
# Middle pile 4: ['35 (Minuspunkte: 2)', '44 (Minuspunkte: 5)', '74 (Minuspunkte: 1)']
#
# Current scores:
# Player 1 has 1 Minuspunkte.
# Player 2 has 2 Minuspunkte.
#
# --- Round 5 ---
#
# Chosen cards before sorting:
# Player 1 chooses 80 (Minuspunkte: 3)
# Player 2 chooses 43 (Minuspunkte: 1)
# Player 2 places 43 (Minuspunkte: 1) on Middle pile 1
# Player 1 places 80 (Minuspunkte: 3) on Middle pile 4
#
# Middle piles after playing the round:
# Middle pile 1: ['14 (Minuspunkte: 1)', '19 (Minuspunkte: 1)', '27 (Minuspunkte: 1)', '43 (Minuspunkte: 1)']
# Middle pile 2: ['4 (Minuspunkte: 5)']
# Middle pile 3: ['52 (Minuspunkte: 1)', '87 (Minuspunkte: 1)']
# Middle pile 4: ['35 (Minuspunkte: 2)', '44 (Minuspunkte: 5)', '74 (Minuspunkte: 1)', '80 (Minuspunkte: 3)']
#
# Current scores:
# Player 1 has 1 Minuspunkte.
# Player 2 has 2 Minuspunkte.
#
# --- Round 6 ---
#
# Chosen cards before sorting:
# Player 1 chooses 99 (Minuspunkte: 5)
# Player 2 chooses 33 (Minuspunkte: 5)
# Player 2 places 33 (Minuspunkte: 5) on Middle pile 2
# Player 1 places 99 (Minuspunkte: 5) on Middle pile 3
#
# Middle piles after playing the round:
# Middle pile 1: ['14 (Minuspunkte: 1)', '19 (Minuspunkte: 1)', '27 (Minuspunkte: 1)', '43 (Minuspunkte: 1)']
# Middle pile 2: ['4 (Minuspunkte: 5)', '33 (Minuspunkte: 5)']
# Middle pile 3: ['52 (Minuspunkte: 1)', '87 (Minuspunkte: 1)', '99 (Minuspunkte: 5)']
# Middle pile 4: ['35 (Minuspunkte: 2)', '44 (Minuspunkte: 5)', '74 (Minuspunkte: 1)', '80 (Minuspunkte: 3)']
#
# Current scores:
# Player 1 has 1 Minuspunkte.
# Player 2 has 2 Minuspunkte.
#
# --- Round 7 ---
#
# Chosen cards before sorting:
# Player 1 chooses 95 (Minuspunkte: 2)
# Player 2 chooses 8 (Minuspunkte: 5)
# Player 2 takes Middle pile 2 with Minuspunkten: 10.
# Player 2 places their own card 8 (Minuspunkte: 5) as new Middle pile 2.
# Player 1 places 95 (Minuspunkte: 2) on Middle pile 4
#
# Middle piles after playing the round:
# Middle pile 1: ['14 (Minuspunkte: 1)', '19 (Minuspunkte: 1)', '27 (Minuspunkte: 1)', '43 (Minuspunkte: 1)']
# Middle pile 2: ['8 (Minuspunkte: 5)']
# Middle pile 3: ['52 (Minuspunkte: 1)', '87 (Minuspunkte: 1)', '99 (Minuspunkte: 5)']
# Middle pile 4: ['35 (Minuspunkte: 2)', '44 (Minuspunkte: 5)', '74 (Minuspunkte: 1)', '80 (Minuspunkte: 3)', '95 (Minuspunkte: 2)']
#
# Current scores:
# Player 1 has 1 Minuspunkte.
# Player 2 has 12 Minuspunkte.
#
# --- Round 8 ---
#
# Chosen cards before sorting:
# Player 1 chooses 41 (Minuspunkte: 1)
# Player 2 chooses 45 (Minuspunkte: 2)
# Player 1 places 41 (Minuspunkte: 1) on Middle pile 2
# Player 2 places 45 (Minuspunkte: 2) on Middle pile 1
#
# Middle piles after playing the round:
# Middle pile 1: ['14 (Minuspunkte: 1)', '19 (Minuspunkte: 1)', '27 (Minuspunkte: 1)', '43 (Minuspunkte: 1)', '45 (Minuspunkte: 2)']
# Middle pile 2: ['8 (Minuspunkte: 5)', '41 (Minuspunkte: 1)']
# Middle pile 3: ['52 (Minuspunkte: 1)', '87 (Minuspunkte: 1)', '99 (Minuspunkte: 5)']
# Middle pile 4: ['35 (Minuspunkte: 2)', '44 (Minuspunkte: 5)', '74 (Minuspunkte: 1)', '80 (Minuspunkte: 3)', '95 (Minuspunkte: 2)']
#
# Current scores:
# Player 1 has 1 Minuspunkte.
# Player 2 has 12 Minuspunkte.
#
# --- Round 9 ---
#
# Chosen cards before sorting:
# Player 1 chooses 94 (Minuspunkte: 1)
# Player 2 chooses 78 (Minuspunkte: 1)
# Player 2 places 78 (Minuspunkte: 1) on Middle pile 1
# Player 1 places 94 (Minuspunkte: 1) on Middle pile 1
#
# Middle piles after playing the round:
# Middle pile 1: ['14 (Minuspunkte: 1)', '19 (Minuspunkte: 1)', '27 (Minuspunkte: 1)', '43 (Minuspunkte: 1)', '45 (Minuspunkte: 2)', '78 (Minuspunkte: 1)', '94 (Minuspunkte: 1)']
# Middle pile 2: ['8 (Minuspunkte: 5)', '41 (Minuspunkte: 1)']
# Middle pile 3: ['52 (Minuspunkte: 1)', '87 (Minuspunkte: 1)', '99 (Minuspunkte: 5)']
# Middle pile 4: ['35 (Minuspunkte: 2)', '44 (Minuspunkte: 5)', '74 (Minuspunkte: 1)', '80 (Minuspunkte: 3)', '95 (Minuspunkte: 2)']
#
# Current scores:
# Player 1 has 1 Minuspunkte.
# Player 2 has 12 Minuspunkte.
#
# --- Round 10 ---
#
# Chosen cards before sorting:
# Player 1 chooses 51 (Minuspunkte: 1)
# Player 2 chooses 96 (Minuspunkte: 1)
# Player 1 places 51 (Minuspunkte: 1) on Middle pile 2
# Player 2 places 96 (Minuspunkte: 1) on Middle pile 4
#
# Middle piles after playing the round:
# Middle pile 1: ['14 (Minuspunkte: 1)', '19 (Minuspunkte: 1)', '27 (Minuspunkte: 1)', '43 (Minuspunkte: 1)', '45 (Minuspunkte: 2)', '78 (Minuspunkte: 1)', '94 (Minuspunkte: 1)']
# Middle pile 2: ['8 (Minuspunkte: 5)', '41 (Minuspunkte: 1)', '51 (Minuspunkte: 1)']
# Middle pile 3: ['52 (Minuspunkte: 1)', '87 (Minuspunkte: 1)', '99 (Minuspunkte: 5)']
# Middle pile 4: ['35 (Minuspunkte: 2)', '44 (Minuspunkte: 5)', '74 (Minuspunkte: 1)', '80 (Minuspunkte: 3)', '95 (Minuspunkte: 2)', '96 (Minuspunkte: 1)']
#
# Current scores:
# Player 1 has 1 Minuspunkte.
# Player 2 has 12 Minuspunkte.
#
# --- Game Over ---
# Final scores:
# Player 1 has 1 Minuspunkte.
# Player 2 has 12 Minuspunkte.

# %%
import random

# Class for a card
class Card:
    def __init__(self, value):
        self.value = value
        self.minus_points = self.calculate_minus_points(value)

    def calculate_minus_points(self, value):
        if value == 55:  # Card with the value 55 always has 7 penalty points
            return 7
        elif value % 10 == 0:  # Divisible by 10
            return 3
        elif value % 5 == 0:  # Ends with 5
            return 2
        else:
            return 1

    def __str__(self):
        return f"{self.value} (Minuspunkte: {self.minus_points})"

# Class for a player
class Player:
    def __init__(self, name):
        self.name = name
        self.hand = []
        self.points = 0

    def draw_cards(self, deck, num_cards=10):
        for _ in range(num_cards):
            if deck:
                self.hand.append(deck.pop())

    def choose_card(self):
        if not self.hand:
            return None
        chosen_card = random.choice(self.hand)
        self.hand.remove(chosen_card)
        return chosen_card

# Function to initialize the game
def initialize_game(num_players):
    # Create a deck of cards (1 to 104)
    deck = [Card(value) for value in range(1, 105)]
    random.shuffle(deck)

    # Create players
    players = [Player(f"Player {i + 1}") for i in range(num_players)]

    # Each player draws 10 cards
    for player in players:
        player.draw_cards(deck)

    # Initialize middle piles with the first four cards from the deck
    middle_piles = [[deck.pop()] for _ in range(4)]

    return players, middle_piles

# Function to play a round of the game
def play_round(players, middle_piles):
    chosen_cards = {}

    # Each player chooses a card and stores it in chosen_cards dictionary
    for player in players:
        chosen_card = player.choose_card()
        if chosen_card:
            chosen_cards[player.name] = chosen_card

    print("\nChosen cards before sorting:")
    for player_name, card in chosen_cards.items():
        print(f"{player_name} chooses {card}")

    # Sort chosen cards by their values (ascending order)
    sorted_chosen_cards = sorted(chosen_cards.items(), key=lambda x: x[1].value)

    # Place chosen cards on the middle piles or take the pile if necessary
    for player_name, card in sorted_chosen_cards:
        placed = False

        # Find the pile with the highest top card that is still lower than the chosen card.
        best_pile_index = -1
        best_top_value = -1

        for i in range(len(middle_piles)):
            top_card_value = middle_piles[i][-1].value

            if top_card_value < card.value and top_card_value > best_top_value:
                best_top_value = top_card_value
                best_pile_index = i

        if best_pile_index != -1:
            # Check if the pile already has 5 cards
            if len(middle_piles[best_pile_index]) == 5:
                # Player takes the first 5 cards as minus points
                points_gained = sum(c.minus_points for c in middle_piles[best_pile_index])
                players[[p.name for p in players].index(player_name)].points += points_gained

                print(f"{player_name} takes Middle pile {best_pile_index + 1} with Minuspunkten: {points_gained}.")

                # Reset the pile with the 6th card as the new first card
                middle_piles[best_pile_index] = [card]
                print(f"{player_name} places their own card {card} as new Middle pile {best_pile_index + 1}.")
            else:
                # Add the card to the pile
                middle_piles[best_pile_index].append(card)
                print(f"{player_name} places {card} on Middle pile {best_pile_index + 1}")
            placed = True

        if not placed:
            # If no suitable pile was found, take the pile with the fewest cards.
            min_length_index = min(range(len(middle_piles)), key=lambda i: len(middle_piles[i]))

            points_gained = sum(c.minus_points for c in middle_piles[min_length_index])
            players[[p.name for p in players].index(player_name)].points += points_gained

            print(f"{player_name} takes Middle pile {min_length_index + 1} with Minuspunkten: {points_gained}.")

            # Clear the pile after taking it and add their own card as new pile.
            middle_piles[min_length_index] = [card]
            print(f"{player_name} places their own card {card} as new Middle pile {min_length_index + 1}.")

# Main function to run the game
def play_game(num_players):
    players, middle_piles = initialize_game(num_players)

    print("Initial hands:")
    for player in players:
        print(f"{player.name}'s hand: {[str(card) for card in player.hand]}")

    print("\nMiddle piles before starting:")
    for i, pile in enumerate(middle_piles):
        print(f"Middle pile {i + 1}: {[str(card) for card in pile]}")

    # Play rounds until all cards are played
    round_number = 1
    while any(player.hand for player in players):
        print(f"\n--- Round {round_number} ---")
        play_round(players, middle_piles)

        print("\nMiddle piles after playing the round:")
        for i, pile in enumerate(middle_piles):
            print(f"Middle pile {i + 1}: {[str(card) for card in pile]}")

        print("\nCurrent scores:")
        for player in players:
            print(f"{player.name} has {player.points} Minuspunkte.")

        round_number += 1

    # Display final scores
    print("\n--- Game Over ---")
    print("Final scores:")
    for player in players:
        print(f"{player.name} has {player.points} Minuspunkte.")

# Start the game with user input for number of players
def get_num_players():
    while True:
        try:
            num_players = int(input("Enter the number of players (2-10): "))
            if 2 <= num_players <= 10:
                return num_players
            else:
                print("Please enter a number between 2 and 10.")
        except ValueError:
            print("Invalid input. Please enter a number.")

# Run the game
num_players = get_num_players()
play_game(num_players)
# Out:
# Enter the number of players (2-10):  3
# Initial hands:
# Player 1's hand: ['30 (Minuspunkte: 3)', '12 (Minuspunkte: 1)', '8 (Minuspunkte: 1)', '79 (Minuspunkte: 1)', '84 (Minuspunkte: 1)', '19 (Minuspunkte: 1)', '32 (Minuspunkte: 1)', '28 (Minuspunkte: 1)', '70 (Minuspunkte: 3)', '104 (Minuspunkte: 1)']
# Player 2's hand: ['4 (Minuspunkte: 1)', '96 (Minuspunkte: 1)', '55 (Minuspunkte: 7)', '5 (Minuspunkte: 2)', '83 (Minuspunkte: 1)', '18 (Minuspunkte: 1)', '31 (Minuspunkte: 1)', '14 (Minuspunkte: 1)', '51 (Minuspunkte: 1)', '48 (Minuspunkte: 1)']
# Player 3's hand: ['9 (Minuspunkte: 1)', '103 (Minuspunkte: 1)', '16 (Minuspunkte: 1)', '20 (Minuspunkte: 3)', '43 (Minuspunkte: 1)', '102 (Minuspunkte: 1)', '86 (Minuspunkte: 1)', '101 (Minuspunkte: 1)', '71 (Minuspunkte: 1)', '47 (Minuspunkte: 1)']
#
# Middle piles before starting:
# Middle pile 1: ['49 (Minuspunkte: 1)']
# Middle pile 2: ['15 (Minuspunkte: 2)']
# Middle pile 3: ['3 (Minuspunkte: 1)']
# Middle pile 4: ['85 (Minuspunkte: 2)']
#
# --- Round 1 ---
#
# Chosen cards before sorting:
# Player 1 chooses 19 (Minuspunkte: 1)
# Player 2 chooses 83 (Minuspunkte: 1)
# Player 3 chooses 71 (Minuspunkte: 1)
# Player 1 places 19 (Minuspunkte: 1) on Middle pile 2
# Player 3 places 71 (Minuspunkte: 1) on Middle pile 1
# Player 2 places 83 (Minuspunkte: 1) on Middle pile 1
#
# Middle piles after playing the round:
# Middle pile 1: ['49 (Minuspunkte: 1)', '71 (Minuspunkte: 1)', '83 (Minuspunkte: 1)']
# Middle pile 2: ['15 (Minuspunkte: 2)', '19 (Minuspunkte: 1)']
# Middle pile 3: ['3 (Minuspunkte: 1)']
# Middle pile 4: ['85 (Minuspunkte: 2)']
#
# Current scores:
# Player 1 has 0 Minuspunkte.
# Player 2 has 0 Minuspunkte.
# Player 3 has 0 Minuspunkte.
#
# --- Round 2 ---
#
# Chosen cards before sorting:
# Player 1 chooses 104 (Minuspunkte: 1)
# Player 2 chooses 14 (Minuspunkte: 1)
# Player 3 chooses 43 (Minuspunkte: 1)
# Player 2 places 14 (Minuspunkte: 1) on Middle pile 3
# Player 3 places 43 (Minuspunkte: 1) on Middle pile 2
# Player 1 places 104 (Minuspunkte: 1) on Middle pile 4
#
# Middle piles after playing the round:
# Middle pile 1: ['49 (Minuspunkte: 1)', '71 (Minuspunkte: 1)', '83 (Minuspunkte: 1)']
# Middle pile 2: ['15 (Minuspunkte: 2)', '19 (Minuspunkte: 1)', '43 (Minuspunkte: 1)']
# Middle pile 3: ['3 (Minuspunkte: 1)', '14 (Minuspunkte: 1)']
# Middle pile 4: ['85 (Minuspunkte: 2)', '104 (Minuspunkte: 1)']
#
# Current scores:
# Player 1 has 0 Minuspunkte.
# Player 2 has 0 Minuspunkte.
# Player 3 has 0 Minuspunkte.
#
# --- Round 3 ---
#
# Chosen cards before sorting:
# Player 1 chooses 79 (Minuspunkte: 1)
# Player 2 chooses 48 (Minuspunkte: 1)
# Player 3 chooses 9 (Minuspunkte: 1)
# Player 3 takes Middle pile 3 with Minuspunkten: 2.
# Player 3 places their own card 9 (Minuspunkte: 1) as new Middle pile 3.
# Player 2 places 48 (Minuspunkte: 1) on Middle pile 2
# Player 1 places 79 (Minuspunkte: 1) on Middle pile 2
#
# Middle piles after playing the round:
# Middle pile 1: ['49 (Minuspunkte: 1)', '71 (Minuspunkte: 1)', '83 (Minuspunkte: 1)']
# Middle pile 2: ['15 (Minuspunkte: 2)', '19 (Minuspunkte: 1)', '43 (Minuspunkte: 1)', '48 (Minuspunkte: 1)', '79 (Minuspunkte: 1)']
# Middle pile 3: ['9 (Minuspunkte: 1)']
# Middle pile 4: ['85 (Minuspunkte: 2)', '104 (Minuspunkte: 1)']
#
# Current scores:
# Player 1 has 0 Minuspunkte.
# Player 2 has 0 Minuspunkte.
# Player 3 has 2 Minuspunkte.
#
# --- Round 4 ---
#
# Chosen cards before sorting:
# Player 1 chooses 70 (Minuspunkte: 3)
# Player 2 chooses 5 (Minuspunkte: 2)
# Player 3 chooses 47 (Minuspunkte: 1)
# Player 2 takes Middle pile 3 with Minuspunkten: 1.
# Player 2 places their own card 5 (Minuspunkte: 2) as new Middle pile 3.
# Player 3 places 47 (Minuspunkte: 1) on Middle pile 3
# Player 1 places 70 (Minuspunkte: 3) on Middle pile 3
#
# Middle piles after playing the round:
# Middle pile 1: ['49 (Minuspunkte: 1)', '71 (Minuspunkte: 1)', '83 (Minuspunkte: 1)']
# Middle pile 2: ['15 (Minuspunkte: 2)', '19 (Minuspunkte: 1)', '43 (Minuspunkte: 1)', '48 (Minuspunkte: 1)', '79 (Minuspunkte: 1)']
# Middle pile 3: ['5 (Minuspunkte: 2)', '47 (Minuspunkte: 1)', '70 (Minuspunkte: 3)']
# Middle pile 4: ['85 (Minuspunkte: 2)', '104 (Minuspunkte: 1)']
#
# Current scores:
# Player 1 has 0 Minuspunkte.
# Player 2 has 1 Minuspunkte.
# Player 3 has 2 Minuspunkte.
#
# --- Round 5 ---
#
# Chosen cards before sorting:
# Player 1 chooses 30 (Minuspunkte: 3)
# Player 2 chooses 4 (Minuspunkte: 1)
# Player 3 chooses 102 (Minuspunkte: 1)
# Player 2 takes Middle pile 4 with Minuspunkten: 3.
# Player 2 places their own card 4 (Minuspunkte: 1) as new Middle pile 4.
# Player 1 places 30 (Minuspunkte: 3) on Middle pile 4
# Player 3 places 102 (Minuspunkte: 1) on Middle pile 1
#
# Middle piles after playing the round:
# Middle pile 1: ['49 (Minuspunkte: 1)', '71 (Minuspunkte: 1)', '83 (Minuspunkte: 1)', '102 (Minuspunkte: 1)']
# Middle pile 2: ['15 (Minuspunkte: 2)', '19 (Minuspunkte: 1)', '43 (Minuspunkte: 1)', '48 (Minuspunkte: 1)', '79 (Minuspunkte: 1)']
# Middle pile 3: ['5 (Minuspunkte: 2)', '47 (Minuspunkte: 1)', '70 (Minuspunkte: 3)']
# Middle pile 4: ['4 (Minuspunkte: 1)', '30 (Minuspunkte: 3)']
#
# Current scores:
# Player 1 has 0 Minuspunkte.
# Player 2 has 4 Minuspunkte.
# Player 3 has 2 Minuspunkte.
#
# --- Round 6 ---
#
# Chosen cards before sorting:
# Player 1 chooses 32 (Minuspunkte: 1)
# Player 2 chooses 51 (Minuspunkte: 1)
# Player 3 chooses 20 (Minuspunkte: 3)
# Player 3 takes Middle pile 4 with Minuspunkten: 4.
# Player 3 places their own card 20 (Minuspunkte: 3) as new Middle pile 4.
# Player 1 places 32 (Minuspunkte: 1) on Middle pile 4
# Player 2 places 51 (Minuspunkte: 1) on Middle pile 4
#
# Middle piles after playing the round:
# Middle pile 1: ['49 (Minuspunkte: 1)', '71 (Minuspunkte: 1)', '83 (Minuspunkte: 1)', '102 (Minuspunkte: 1)']
# Middle pile 2: ['15 (Minuspunkte: 2)', '19 (Minuspunkte: 1)', '43 (Minuspunkte: 1)', '48 (Minuspunkte: 1)', '79 (Minuspunkte: 1)']
# Middle pile 3: ['5 (Minuspunkte: 2)', '47 (Minuspunkte: 1)', '70 (Minuspunkte: 3)']
# Middle pile 4: ['20 (Minuspunkte: 3)', '32 (Minuspunkte: 1)', '51 (Minuspunkte: 1)']
#
# Current scores:
# Player 1 has 0 Minuspunkte.
# Player 2 has 4 Minuspunkte.
# Player 3 has 6 Minuspunkte.
#
# --- Round 7 ---
#
# Chosen cards before sorting:
# Player 1 chooses 84 (Minuspunkte: 1)
# Player 2 chooses 31 (Minuspunkte: 1)
# Player 3 chooses 86 (Minuspunkte: 1)
# Player 2 takes Middle pile 3 with Minuspunkten: 6.
# Player 2 places their own card 31 (Minuspunkte: 1) as new Middle pile 3.
# Player 1 takes Middle pile 2 with Minuspunkten: 6.
# Player 1 places their own card 84 (Minuspunkte: 1) as new Middle pile 2.
# Player 3 places 86 (Minuspunkte: 1) on Middle pile 2
#
# Middle piles after playing the round:
# Middle pile 1: ['49 (Minuspunkte: 1)', '71 (Minuspunkte: 1)', '83 (Minuspunkte: 1)', '102 (Minuspunkte: 1)']
# Middle pile 2: ['84 (Minuspunkte: 1)', '86 (Minuspunkte: 1)']
# Middle pile 3: ['31 (Minuspunkte: 1)']
# Middle pile 4: ['20 (Minuspunkte: 3)', '32 (Minuspunkte: 1)', '51 (Minuspunkte: 1)']
#
# Current scores:
# Player 1 has 6 Minuspunkte.
# Player 2 has 10 Minuspunkte.
# Player 3 has 6 Minuspunkte.
#
# --- Round 8 ---
#
# Chosen cards before sorting:
# Player 1 chooses 12 (Minuspunkte: 1)
# Player 2 chooses 96 (Minuspunkte: 1)
# Player 3 chooses 16 (Minuspunkte: 1)
# Player 1 takes Middle pile 3 with Minuspunkten: 1.
# Player 1 places their own card 12 (Minuspunkte: 1) as new Middle pile 3.
# Player 3 places 16 (Minuspunkte: 1) on Middle pile 3
# Player 2 places 96 (Minuspunkte: 1) on Middle pile 2
#
# Middle piles after playing the round:
# Middle pile 1: ['49 (Minuspunkte: 1)', '71 (Minuspunkte: 1)', '83 (Minuspunkte: 1)', '102 (Minuspunkte: 1)']
# Middle pile 2: ['84 (Minuspunkte: 1)', '86 (Minuspunkte: 1)', '96 (Minuspunkte: 1)']
# Middle pile 3: ['12 (Minuspunkte: 1)', '16 (Minuspunkte: 1)']
# Middle pile 4: ['20 (Minuspunkte: 3)', '32 (Minuspunkte: 1)', '51 (Minuspunkte: 1)']
#
# Current scores:
# Player 1 has 7 Minuspunkte.
# Player 2 has 10 Minuspunkte.
# Player 3 has 6 Minuspunkte.
#
# --- Round 9 ---
#
# Chosen cards before sorting:
# Player 1 chooses 28 (Minuspunkte: 1)
# Player 2 chooses 18 (Minuspunkte: 1)
# Player 3 chooses 101 (Minuspunkte: 1)
# Player 2 places 18 (Minuspunkte: 1) on Middle pile 3
# Player 1 places 28 (Minuspunkte: 1) on Middle pile 3
# Player 3 places 101 (Minuspunkte: 1) on Middle pile 2
#
# Middle piles after playing the round:
# Middle pile 1: ['49 (Minuspunkte: 1)', '71 (Minuspunkte: 1)', '83 (Minuspunkte: 1)', '102 (Minuspunkte: 1)']
# Middle pile 2: ['84 (Minuspunkte: 1)', '86 (Minuspunkte: 1)', '96 (Minuspunkte: 1)', '101 (Minuspunkte: 1)']
# Middle pile 3: ['12 (Minuspunkte: 1)', '16 (Minuspunkte: 1)', '18 (Minuspunkte: 1)', '28 (Minuspunkte: 1)']
# Middle pile 4: ['20 (Minuspunkte: 3)', '32 (Minuspunkte: 1)', '51 (Minuspunkte: 1)']
#
# Current scores:
# Player 1 has 7 Minuspunkte.
# Player 2 has 10 Minuspunkte.
# Player 3 has 6 Minuspunkte.
#
# --- Round 10 ---
#
# Chosen cards before sorting:
# Player 1 chooses 8 (Minuspunkte: 1)
# Player 2 chooses 55 (Minuspunkte: 7)
# Player 3 chooses 103 (Minuspunkte: 1)
# Player 1 takes Middle pile 4 with Minuspunkten: 5.
# Player 1 places their own card 8 (Minuspunkte: 1) as new Middle pile 4.
# Player 2 places 55 (Minuspunkte: 7) on Middle pile 3
# Player 3 places 103 (Minuspunkte: 1) on Middle pile 1
#
# Middle piles after playing the round:
# Middle pile 1: ['49 (Minuspunkte: 1)', '71 (Minuspunkte: 1)', '83 (Minuspunkte: 1)', '102 (Minuspunkte: 1)', '103 (Minuspunkte: 1)']
# Middle pile 2: ['84 (Minuspunkte: 1)', '86 (Minuspunkte: 1)', '96 (Minuspunkte: 1)', '101 (Minuspunkte: 1)']
# Middle pile 3: ['12 (Minuspunkte: 1)', '16 (Minuspunkte: 1)', '18 (Minuspunkte: 1)', '28 (Minuspunkte: 1)', '55 (Minuspunkte: 7)']
# Middle pile 4: ['8 (Minuspunkte: 1)']
#
# Current scores:
# Player 1 has 12 Minuspunkte.
# Player 2 has 10 Minuspunkte.
# Player 3 has 6 Minuspunkte.
#
# --- Game Over ---
# Final scores:
# Player 1 has 12 Minuspunkte.
# Player 2 has 10 Minuspunkte.
# Player 3 has 6 Minuspunkte.
